# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# **Objetivos:**
#
# - Lista de lenguajes populares para la ciencia de datos
# - Lista de bibliotecas populares que utilizan habitualmente los científicos de datos
# - Tabla de herramientas de la ciencia de datos
# - Evaluaciondes de expresiones aritméticas

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. Matplotlib

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlin

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | GitHub            |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
(3*4)+5
# Out:
# 17

# %%
# Esto convertirá 200 minutos a horas y minutos.
hours = 200 // 60  # División de enteros para horas enteras
minutes = 200 % 60  # Operación para los minutos restantes
print(f"{hours} hours and {minutes} minutes")
# Out:
# 3 hours and 20 minutes

# %% [markdown]
# ## Author
# Susana
